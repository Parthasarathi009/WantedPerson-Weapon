# %%
import cv2
import numpy as np
import boto3, io
import matplotlib.pyplot as plt

# %%
s3 = boto3.client('s3',
                  region_name='us-east-2',
                  aws_access_key_id='AKIA4XEVBWGXROYDINWU',
                  aws_secret_access_key='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')

url_cv = s3.generate_presigned_url('get_object',
                                   Params={'Bucket': 'parthcloudneu',
                                           'Key': '6.mp4'})

print("url_cv: ", url_cv)

#vid = cv2.VideoCapture('https://parthcloudneu.s3.us-east-2.amazonaws.com/6.mp4')

#vid = cv2.VideoCapture(s3.download_fileobj(Bucket='parthcloudneu', Key='6.mp4', Fileobj=io.BytesIO()))
vid = cv2.VideoCapture(url_cv)

Success,first_frame = vid.read()

print("Image shape: ", first_frame.shape)
print('is success', Success)
# Out:
# url_cv:  https://parthcloudneu.s3.amazonaws.com/6.mp4?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA4XEVBWGXROYDINWU%2F20200210%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20200210T232919Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=9154d804d8cce409f315acd2149a6861236c9f29e6217a4df30f0fb48f00a502
# Image shape:  (480, 640, 3)
# is success True

# %%
plt.imshow(first_frame)

# %%
import time
sub= cv2.createBackgroundSubtractorMOG2(history=10, varThreshold=50, detectShadows=False)


while True:
    _, frame = vid.read()
    
    #difference = sub.apply(frame)
    #difference =cv2.absdiff(frame,first_frame)
    #plt.imshow(first_frame)
    #plt.show()
    #plt.imshow(frame)
    #plt.show()
    plt.imshow(difference)
    #plt.show()
    #key = cv2.waitKey(30)
    #if key == 27:
     #   break
vid.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-35-07879cc08444> in <module>()
#       7
#       8     #difference = sub.apply(frame)
# ----> 9     difference =cv2.absdiff(frame,first_frame)
#      10     #plt.imshow(first_frame)
#      11     #plt.show()
#
# error: OpenCV(3.4.2) /tmp/build/80754af9/opencv-suite_1535558553474/work/modules/core/src/arithm.cpp:656: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'
